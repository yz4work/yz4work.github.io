# %% [markdown]
# # 风格迁移
# 代码展示了用不同风格迁移模型运行的结果

# %%
from models.nst import get_transfered_img, save_img
import argparse
parser = argparse.ArgumentParser()
parser.add_argument("-content_path", help="内容", default='./images/content/wh1102.jpg')
parser.add_argument("-style_path", help="风格", default='./images/style/vangogh_starry_night.jpg')
parser.add_argument("-model_path", help="模型", default='./pretrained_models/vgg_conv.pth')
parser.add_argument("-output_path", help="输出路径", default='./images/styled')
parser.add_argument("-fn_name", help="风格图片", default='vg_1.png')
parser.add_argument("-content_layers", help="内容特征", default=['r42'])
parser.add_argument("-style_layers", help="风格特征", default=['r11','r21','r31','r41', 'r51'])
parser.add_argument("-img_size", help="图片尺寸", default=600)
parser.add_argument("-epoch", help="训练次数", default=14)
params = parser.parse_args([])

# %%
out_img = get_transfered_img(params)
# save_img(out_img, params.output_path, params.fn_name)
out_img
# Out:
# Training...: 100%|██████████| 14/14 [00:37<00:00,  2.68s/it]
# <PIL.Image.Image image mode=RGB size=800x600>
